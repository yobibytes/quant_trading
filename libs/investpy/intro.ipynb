# %%
import investpy

# %%
stocks = investpy.get_stocks_list(country='germany')
stocks
# Out:
# ['BASFn',
#  'BAYGn',
#  'ALVG',
#  'ADSGn',
#  'LHAG',
#  'SIEGn',
#  'VOWG',
#  'DBKGn',
#  'CONG',
#  'DPWGn',
#  'DAIGn',
#  'PSHG_p',
#  'HNKG_p',
#  'CBKG',
#  'DB1Gn',
#  'BMWG',
#  'FMEG',
#  'DTEGn',
#  'MANG',
#  'MRCG',
#  'IFXGn',
#  'CECG',
#  'MUVGn',
#  'SAPG',
#  'TKAG',
#  'RHMG',
#  'TUIGn',
#  'WDIG',
#  'LXSG',
#  'BEIG',
#  'FREG',
#  'FNTGn',
#  'SZGG',
#  'A3B',
#  'FRAG',
#  'WCHG',
#  'QSCG',
#  'ZILGn',
#  'VOSG',
#  'KRNG',
#  'G1AG',
#  'HNRGn',
#  'GBFG',
#  'DRWG_p',
#  'SOWGn',
#  'KCOGn',
#  'HOTG',
#  'RWEG',
#  'DEQGn',
#  'NDXG',
#  'NAFG',
#  'A6W',
#  'AIXGn',
#  'RHKG',
#  'GILG',
#  'ABM',
#  'SGCG',
#  'SDFGn',
#  'MTXGn',
#  'SZUG',
#  'HDDG',
#  'ARLG',
#  'B5AG',
#  'DEZG',
#  'SY1G',
#  'CTNGk',
#  'PV',
#  'SNGGk',
#  'HEIG',
#  'AD8',
#  'QIA',
#  'ADC',
#  'UTDI',
#  'LEOGn',
#  'GGS',
#  'AEL',
#  'AF4',
#  'MORG',
#  'M5ZG',
#  'MDNG',
#  'AGM',
#  'AFXG',
#  'BOSSn',
#  'LOGNn',
#  'SIEGn',
#  'BC8G',
#  'ERICb',
#  'MLPG',
# ...

# %%
df = investpy.get_stock_recent_data(stock='bbva', country='spain', as_json=False, order='ascending')
df
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2019-11-04  4.793  4.890  4.760  4.878       0      EUR
# 2019-11-05  4.900  4.973  4.881  4.954       0      EUR
# 2019-11-06  4.980  5.035  4.885  4.904       0      EUR
# 2019-11-07  4.904  4.998  4.885  4.989       0      EUR
# 2019-11-08  4.960  5.004  4.916  4.958       0      EUR
# 2019-11-11  4.925  4.965  4.892  4.944       0      EUR
# 2019-11-12  4.971  5.002  4.907  4.917       0      EUR
# 2019-11-13  4.865  4.880  4.715  4.756       0      EUR
# 2019-11-14  4.764  4.774  4.713  4.740       0      EUR
# 2019-11-15  4.782  4.806  4.732  4.768       0      EUR
# 2019-11-18  4.793  4.822  4.691  4.736       0      EUR
# 2019-11-19  4.760  4.823  4.745  4.762       0      EUR
# 2019-11-20  4.718  4.741  4.660  4.726       0      EUR
# 2019-11-21  4.703  4.772  4.678  4.761       0      EUR
# 2019-11-22  4.782  4.854  4.764  4.798       0      EUR
# 2019-11-25  4.824  4.867  4.798  4.816       0      EUR
# ...

# %%
profile = investpy.get_stock_company_profile(stock='bbva', country='spain', language='english')
profile
# Out:
# {'url': 'https://www.investing.com/equities/bbva-company-profile',
# ...

# %%
df = investpy.get_stock_historical_data(stock='AAPL', country='united states', from_date='01/01/2019', to_date='02/12/2019')

# %%
df
# Out:
#               Open    High     Low   Close  Volume Currency
# Date
# 2019-01-02  154.89  158.85  154.23  157.92       0      USD
# 2019-01-03  143.98  145.72  142.00  142.19       0      USD
# 2019-01-04  144.53  148.55  143.80  148.26       0      USD
# 2019-01-07  148.70  148.83  145.90  147.93       0      USD
# 2019-01-08  149.56  151.82  148.52  150.75       0      USD
# ...            ...     ...     ...     ...     ...      ...
# 2019-11-25  262.71  266.44  262.52  266.37       0      USD
# 2019-11-26  266.94  267.16  262.50  264.29       0      USD
# 2019-11-27  265.58  267.98  265.31  267.84       0      USD
# 2019-11-29  266.14  267.98  265.93  267.25       0      USD
# 2019-12-02  267.55  268.22  263.50  264.56       0      USD
#
# [232 rows x 6 columns]
