# %%
import featuretools as ft
import pandas as pd

pd.options.display.max_colwidth=800

# %%
primitives = ft.list_primitives()

# %%
# aggregations
primitives[primitives['type'] == 'aggregation'].head(100)
# Out:
#                 name         type  \
# 0               skew  aggregation
# 1   avg_time_between  aggregation
# 2       percent_true  aggregation
# 3         num_unique  aggregation
# 4                all  aggregation
# 5                min  aggregation
# 6               last  aggregation
# 7               mean  aggregation
# 8              count  aggregation
# 9                std  aggregation
# 10            median  aggregation
# 11     n_most_common  aggregation
# 12          num_true  aggregation
# 13   time_since_last  aggregation
# 14               max  aggregation
# 15               any  aggregation
# 16           entropy  aggregation
# 17              mode  aggregation
# 18  time_since_first  aggregation
# 19             trend  aggregation
# 20             first  aggregation
# 21               sum  aggregation
#
#                                                                         description
# 0   Computes the extent to which a distribution differs from a normal distribution.
# 1                Computes the average number of seconds between consecutive events.
# 2                                          Determines the percent of `True` values.
# 3                  Determines the number of distinct values, ignoring `NaN` values.
# 4                                    Calculates if all values are 'True' in a list.
# 5                             Calculates the smallest value, ignoring `NaN` values.
# 6                                              Determines the last value in a list.
# 7                                        Computes the average for a list of values.
# 8                           Determines the total number of values, excluding `NaN`.
# 9               Computes the dispersion relative to the mean value, ignoring `NaN`.
# 10                            Determines the middlemost number in a list of values.
# 11                                         Determines the `n` most common elements.
# 12                                              Counts the number of `True` values.
# 13        Calculates the time elapsed since the last datetime (default in seconds).
# 14                             Calculates the highest value, ignoring `NaN` values.
# 15                                     Determines if any value is 'True' in a list.
# 16                                Calculates the entropy for a categorical variable
# 17                                     Determines the most commonly repeated value.
# 18               Calculates the time elapsed since the first datetime (in seconds).
# 19                                    Calculates the trend of a variable over time.
# 20                                            Determines the first value in a list.
# 21                                   Calculates the total addition, ignoring `NaN`.

# %%
# transformations
primitives[primitives['type'] == 'transform'].head(100)
# Out:
#                                name       type  \
# 22              greater_than_scalar  transform
# 23                         latitude  transform
# 24            modulo_numeric_scalar  transform
# 25          subtract_numeric_scalar  transform
# 26                              day  transform
# 27            divide_numeric_scalar  transform
# 28               add_numeric_scalar  transform
# 29                divide_by_feature  transform
# 30                         absolute  transform
# 31              time_since_previous  transform
# 32                 not_equal_scalar  transform
# 33                          cum_max  transform
# 34                              not  transform
# 35                     equal_scalar  transform
# 36                         cum_mean  transform
# 37                             diff  transform
# 38                        num_words  transform
# 39                   divide_numeric  transform
# 40        less_than_equal_to_scalar  transform
# 41                               or  transform
# 42                            month  transform
# 43                 multiply_numeric  transform
# 44                          weekday  transform
# 45                        less_than  transform
# 46          multiply_numeric_scalar  transform
# 47                           minute  transform
# 48            greater_than_equal_to  transform
# 49                        longitude  transform
# 50                modulo_by_feature  transform
# 51  scalar_subtract_numeric_feature  transform
# 52                             hour  transform
# 53                              and  transform
# 54                       is_weekend  transform
# 55                     greater_than  transform
# 56                   modulo_numeric  transform
# 57                 subtract_numeric  transform
# 58                      add_numeric  transform
# 59                          is_null  transform
# 60                       percentile  transform
# 61                          cum_sum  transform
# 62                        not_equal  transform
# 63                          cum_min  transform
# 64                           negate  transform
# 65                       time_since  transform
# 66                            equal  transform
# 67                        cum_count  transform
# 68                             isin  transform
# 69                   num_characters  transform
# 70                             year  transform
# 71                 less_than_scalar  transform
# 72               less_than_equal_to  transform
# 73                 multiply_boolean  transform
# 74                             week  transform
# 75     greater_than_equal_to_scalar  transform
# 76                        haversine  transform
# 77                           second  transform
#
#                                                                     description
# 22                        Determines if values are greater than a given scalar.
# 23                   Returns the first tuple value in a list of LatLong tuples.
# 24                   Return the modulo of each element in the list by a scalar.
# 25                             Subtract a scalar from each element in the list.
# 26                             Determines the day of the month from a datetime.
# 27                                 Divide each element in the list by a scalar.
# 28                                      Add a scalar to each value in the list.
# 29                                   Divide a scalar by each value in the list.
# 30                                     Computes the absolute value of a number.
# 31                         Compute the time since the previous entry in a list.
# 32              Determines if values in a list are not equal to a given scalar.
# 33                                           Calculates the cumulative maximum.
# 34                                                     Negates a boolean value.
# 35                  Determines if values in a list are equal to a given scalar.
# 36                                              Calculates the cumulative mean.
# 37                   Compute the difference between the value in a list and the
# 38           Determines the number of words in a string by counting the spaces.
# 39                                          Element-wise division of two lists.
# 40               Determines if values are less than or equal to a given scalar.
# 41                                        Element-wise logical OR of two lists.
# 42                                    Determines the month value of a datetime.
# 43                                    Element-wise multiplication of two lists.
# 44                              Determines the day of the week from a datetime.
# 45                 Determines if values in one list are less than another list.
# 46                               Multiply each element in the list by a scalar.
# 47                                  Determines the minutes value of a datetime.
# 48  Determines if values in one list are greater than or equal to another list.
# 49                  Returns the second tuple value in a list of LatLong tuples.
# 50                   Return the modulo of a scalar by each element in the list.
# 51                         Subtract each value in the list from a given scalar.
# 52                                     Determines the hour value of a datetime.
# 53                                       Element-wise logical AND of two lists.
# 54                                     Determines if a date falls on a weekend.
# 55              Determines if values in one list are greater than another list.
# 56                                            Element-wise modulo of two lists.
# 57                                       Element-wise subtraction of two lists.
# 58                                          Element-wise addition of two lists.
# 59                                               Determines if a value is null.
# 60                     Determines the percentile rank for each value in a list.
# 61                                               Calculates the cumulative sum.
# 62              Determines if values in one list are not equal to another list.
# 63                                           Calculates the cumulative minimum.
# 64                                                     Negates a numeric value.
# 65                 Calculates time from a value to a specified cutoff datetime.
# 66                  Determines if values in one list are equal to another list.
# 67                                             Calculates the cumulative count.
# 68                    Determines whether a value is present in a provided list.
# 69                             Calculates the number of characters in a string.
# 70                                     Determines the year value of a datetime.
# 71                           Determines if values are less than a given scalar.
# 72     Determines if values in one list are less than or equal to another list.
# 73                  Element-wise multiplication of two lists of boolean values.
# 74                             Determines the week of the year from a datetime.
# 75            Determines if values are greater than or equal to a given scalar.
# 76            Calculates the approximate haversine distance between two LatLong
# 77                                  Determines the seconds value of a datetime.
