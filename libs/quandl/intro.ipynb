# %%
import quandl
import matplotlib.pyplot as plt
import os

# %%
# set env via .env file
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), verbose=True)
# Out:
# True

# %%
data = quandl.get("WIKI/AAPL", start_date="2018-01-01", end_date="2019-12-02", api_key=os.environ['QUANDL_API_KEY'])

# %%
data
# Out:
#                Open      High       Low    Close      Volume  Ex-Dividend  \
# Date
# 2018-01-02  170.160  172.3000  169.2600  172.260  25048048.0          0.0
# 2018-01-03  172.530  174.5500  171.9600  172.230  28819653.0          0.0
# 2018-01-04  172.540  173.4700  172.0800  173.030  22211345.0          0.0
# 2018-01-05  173.440  175.3700  173.0500  175.000  23016177.0          0.0
# 2018-01-08  174.350  175.6100  173.9300  174.350  20134092.0          0.0
# 2018-01-09  174.550  175.0600  173.4100  174.330  21262614.0          0.0
# 2018-01-10  173.160  174.3000  173.0000  174.290  23589129.0          0.0
# 2018-01-11  174.590  175.4886  174.4900  175.280  17523256.0          0.0
# 2018-01-12  176.180  177.3600  175.6500  177.090  25039531.0          0.0
# 2018-01-16  177.900  179.3900  176.1400  176.190  29159005.0          0.0
# 2018-01-17  176.150  179.2500  175.0700  179.100  32752734.0          0.0
# 2018-01-18  179.370  180.1000  178.2500  179.260  30234512.0          0.0
# ...

# %%
data.Close.plot()
plt.show()
